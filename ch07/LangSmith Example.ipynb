# %%
from dotenv import load_dotenv
import os
import json
from openai import OpenAI
import asyncio
from agents import Agent, Runner, set_trace_processors
from langsmith.integrations.openai_agents_sdk import OpenAIAgentsTracingProcessor

load_dotenv()   # loads .env from current directory

print(os.getenv("OPENAI_API_KEY"))
print("Tracing:", os.getenv("LANGSMITH_TRACING"))
print("Project:", os.getenv("LANGSMITH_PROJECT"))
print("Key exists:", bool(os.getenv("LANGSMITH_API_KEY")))
# Out:
# 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
# Tracing: true
# Project: "Q & A chatbot"
# Key exists: True

# %%
import asyncio
from dotenv import load_dotenv
from agents import Agent, Runner, set_trace_processors
from langsmith.integrations.openai_agents_sdk import OpenAIAgentsTracingProcessor

load_dotenv()

set_trace_processors([OpenAIAgentsTracingProcessor()])


async def main():
    agent = Agent(
        name="Captain Obvious",
        instructions="You are Captain Obvious, the world's most literal technical support agent.",
    )

    question = "Why is my code failing when I try to divide by zero?"
    
    result = await Runner.run(agent, question)

    print(result.final_output)


await main()
# Out:
# Your code is failing when you try to divide by zero because dividing any number by zero is mathematically undefined. In most programming languages, attempting to divide by zero will cause a runtime error or exception, which causes your code to fail. To avoid this, make sure the number you are dividing by is not zero before performing the division.
